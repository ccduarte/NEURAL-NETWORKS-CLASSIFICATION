# %% [markdown]
# # Projeto Integrado Final - Deep Learning
#
# Desenvolvimento de modelo classificação utilizando Redes Neurais Convolucionais (CNN) ou Redes Neurais Recorrentes (RNN), com base na tendencia de mercado dos ultimos 15 dias, considerando o "close" da ação em base de dados suavizada.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint
from collections import defaultdict

# %%
df_train = pd.read_csv('../src/data/PETR4.SA/treino.csv')
df_test = pd.read_csv('../src/data/PETR4.SA/teste.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_train.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0           1  2000-01-24  1.274788        1.347845     -1           1.283923
# 1           2  2000-01-25  1.274788        1.340540     -1           1.274788
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           1.311824           1.314787           1.324169           1.317996
# 1           1.283923           1.311824           1.314787           1.324169
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           1.333305           1.314787           1.353798           1.351823
# 1           1.317996           1.333305           1.314787           1.353798
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            1.385896            1.357995            1.351823
# 1            1.351823            1.385896            1.357995
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            1.356514            1.370341            1.450586
# 1            1.351823            1.356514            1.370341

# %%
df_test.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0        4809  2019-02-26  9.467936        9.376527      1           9.510681
# 1        4810  2019-02-27  9.646040        9.403478      1           9.467936
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           9.663848           9.760024           9.631790           9.752899
# 1           9.510681           9.663848           9.760024           9.631790
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           9.532050           9.560549           9.599731           9.279146
# 1           9.752899           9.532050           9.560549           9.599731
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            9.161598            8.848140            8.951439
# 1            9.279146            9.161598            8.848140
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            8.937191            9.079673            9.289832
# 1            8.951439            8.937191            9.079673

# %%
nome_arquivo = 'PETR4'
# EDA
print(f"EDA para {nome_arquivo}:")
print(f"Descrição dos dados:\n{df_train.describe()}\n")
print(f"Contagem de valores NaN por coluna:\n{df_train.isna().sum()}\n")
print(f"Contagem dos rótulos:\n{df_train['Label'].value_counts()}\n")
# Out:
# EDA para PETR4:
# Descrição dos dados:
#         Unnamed: 0        Close  Smoothed_Close        Label  \
# count  4808.000000  4808.000000     4808.000000  4808.000000
# mean   2404.500000     5.126396        5.111402    -0.103993
# std    1388.094377     2.810534        2.790427     0.994681
# min       1.000000     1.080224        1.200894    -1.000000
# 25%    1202.750000     2.523248        2.533339    -1.000000
# 50%    2404.500000     5.331852        5.349307    -1.000000
# 75%    3606.250000     6.990364        6.965855     1.000000
# max    4808.000000    14.551721       13.432679     1.000000
#
#        Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean            5.124685           5.122948           5.121191
# std             2.810369           2.810144           2.809884
# min             1.080224           1.080224           1.080224
# 25%             2.519004           2.518208           2.516232
# 50%             5.331822           5.330961           5.330100
# 75%             6.990364           6.990364           6.984855
# max            14.551721          14.551721          14.551721
#
#        Past_4_Days_Close  Past_5_Days_Close  Past_6_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean            5.119464           5.117709           5.116004
# std             2.809664           2.809404           2.809212
# min             1.080224           1.080224           1.080224
# 25%             2.513835           2.508511           2.506351
# 50%             5.330100           5.329587           5.327880
# 75%             6.982575           6.981311           6.979728
# max            14.551721          14.551721          14.551721
#
#        Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# count        4808.000000        4808.000000        4808.000000
# mean            5.114289           5.112574           5.110925
# std             2.809015           2.808793           2.808673
# min             1.080224           1.080224           1.080224
# 25%             2.506119           2.506119           2.505502
# 50%             5.325965           5.325195           5.323849
# 75%             6.977312           6.972238           6.969759
# max            14.551721          14.551721          14.551721
#
#        Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# count         4808.000000         4808.000000         4808.000000
# mean             5.109308            5.107750            5.106169
# std              2.808579            2.808582            2.808557
# min              1.080224            1.080224            1.080224
# 25%              2.502724            2.499175            2.496860
# 50%              5.322553            5.322385            5.321037
# 75%              6.968959            6.967902            6.966150
# max             14.551721           14.551721           14.551721
#
#        Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# count         4808.000000         4808.000000         4808.000000
# mean             5.104593            5.102989            5.101359
# std              2.808534            2.808465            2.808309
# min              1.080224            1.080224            1.080224
# 25%              2.496860            2.496860            2.496860
# 50%              5.319856            5.319856            5.319856
# 75%              6.963105            6.961744            6.959695
# max             14.551721           14.551721           14.551721
#
# Contagem de valores NaN por coluna:
# Unnamed: 0            0
# Date                  0
# Close                 0
# Smoothed_Close        0
# Label                 0
# Past_1_Days_Close     0
# Past_2_Days_Close     0
# Past_3_Days_Close     0
# Past_4_Days_Close     0
# Past_5_Days_Close     0
# Past_6_Days_Close     0
# Past_7_Days_Close     0
# Past_8_Days_Close     0
# Past_9_Days_Close     0
# Past_10_Days_Close    0
# Past_11_Days_Close    0
# Past_12_Days_Close    0
# Past_13_Days_Close    0
# Past_14_Days_Close    0
# Past_15_Days_Close    0
# dtype: int64
#
# Contagem dos rótulos:
# Label
# -1    2654
#  1    2154
# Name: count, dtype: int64

# %%
# COMPARAÇÃO ENTRE PREÇOS DE FECHAMENTO E PREÇOS DE FECHAMENTO SUAVIZADOS
plt.figure(figsize=(14, 7))
plt.plot(df_train['Close'], label='Close')
plt.plot(df_train['Smoothed_Close'], label='Smoothed Close')
plt.title(f'Preços de Fechamento e Suavizados - {nome_arquivo}')
plt.legend()
plt.show()

# %%
# DISTRIBUIÇÃO DOS RÓTULOS
sns.countplot(x='Label', data=df_train)
plt.title(f'Distribuição de Classes - {nome_arquivo}')
plt.show()

# %% [markdown]
# ## Treinamento de modelo de Redes Neurais Recorrentes (RNN)

# %%
## NORMALIZAÇÃO DOS DADOS

# Normalizador para as features
scaler = StandardScaler()

# Função para converter rótulos em formato categórico
def converter_para_categorico(y):
    if y.min() == -1:  # Se os rótulos forem -1 e 1
        y = (y + 1) // 2  # Converter rótulos para 0 e 1
    return to_categorical(y)

X_train = df_train.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_train = df_train['Label']

X_test = df_test.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_test = df_test['Label']

# Normalizar as features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Converter os rótulos para formato categórico
y_train_cat = converter_para_categorico(y_train)
y_test_cat = converter_para_categorico(y_test)

# %%
# Cria e treina a rede LSTM
historicos = {}

model_rnn = Sequential([     
        LSTM(150, return_sequences=True, input_shape=(X_train.shape[1], 1)),
        ##Dropout(0.1),
        LSTM(50),
        Dense(y_train_cat.shape[1], activation='sigmoid')
    ])

model_rnn.compile(loss='binary_crossentropy', metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='../models/melhor_rnn_PETR4.keras', verbose=1,  save_best_only=True, monitor='val_accuracy')

historico_rnn = model_rnn.fit(X_train, y_train_cat, epochs=70, batch_size=8, validation_split=0.1, verbose=1, callbacks=[checkpointer],shuffle=True)
# Out:
# Epoch 1/70
# /Users/cintia.duarte/Documents/develop/NEURAL-NETWORKS-REGRESSION/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 535/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5408 - loss: 0.6903
# Epoch 1: val_accuracy improved from -inf to 0.47193, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5411 - loss: 0.6902 - val_accuracy: 0.4719 - val_loss: 0.6759
# Epoch 2/70
# 538/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5908 - loss: 0.6601
# Epoch 2: val_accuracy improved from 0.47193 to 0.61331, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5909 - loss: 0.6600 - val_accuracy: 0.6133 - val_loss: 0.6164
# Epoch 3/70
# 535/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6461 - loss: 0.6120
# Epoch 3: val_accuracy improved from 0.61331 to 0.74428, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6463 - loss: 0.6118 - val_accuracy: 0.7443 - val_loss: 0.4847
# Epoch 4/70
# 539/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6935 - loss: 0.5738
# Epoch 4: val_accuracy did not improve from 0.74428
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6935 - loss: 0.5738 - val_accuracy: 0.6736 - val_loss: 0.5621
# Epoch 5/70
# 540/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6922 - loss: 0.5606
# Epoch 5: val_accuracy improved from 0.74428 to 0.81705, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6922 - loss: 0.5606 - val_accuracy: 0.8170 - val_loss: 0.4293
# Epoch 6/70
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7097 - loss: 0.5399
# Epoch 6: val_accuracy did not improve from 0.81705
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7097 - loss: 0.5399 - val_accuracy: 0.8025 - val_loss: 0.4506
# Epoch 7/70
# 538/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7154 - loss: 0.5344
# Epoch 7: val_accuracy improved from 0.81705 to 0.82744, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7154 - loss: 0.5345 - val_accuracy: 0.8274 - val_loss: 0.4176
# Epoch 8/70
# 538/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6915 - loss: 0.5507
# Epoch 8: val_accuracy did not improve from 0.82744
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6915 - loss: 0.5506 - val_accuracy: 0.7505 - val_loss: 0.4809
# Epoch 9/70
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7147 - loss: 0.5287
# Epoch 9: val_accuracy did not improve from 0.82744
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7147 - loss: 0.5287 - val_accuracy: 0.7817 - val_loss: 0.4426
# Epoch 10/70
# 540/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7098 - loss: 0.5249
# Epoch 10: val_accuracy did not improve from 0.82744
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7098 - loss: 0.5249 - val_accuracy: 0.8233 - val_loss: 0.4217
# Epoch 11/70
# 538/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7340 - loss: 0.5012
# Epoch 11: val_accuracy did not improve from 0.82744
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7340 - loss: 0.5013 - val_accuracy: 0.7318 - val_loss: 0.4925
# Epoch 12/70
# 537/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7423 - loss: 0.5007
# Epoch 12: val_accuracy did not improve from 0.82744
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7422 - loss: 0.5008 - val_accuracy: 0.7630 - val_loss: 0.4564
# Epoch 13/70
# 538/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7492 - loss: 0.4966
# Epoch 13: val_accuracy improved from 0.82744 to 0.83576, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7491 - loss: 0.4966 - val_accuracy: 0.8358 - val_loss: 0.4052
# Epoch 14/70
# 540/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7282 - loss: 0.5004
# Epoch 14: val_accuracy did not improve from 0.83576
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7283 - loss: 0.5003 - val_accuracy: 0.7838 - val_loss: 0.4495
# Epoch 15/70
# 537/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7448 - loss: 0.4966
# Epoch 15: val_accuracy did not improve from 0.83576
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7448 - loss: 0.4966 - val_accuracy: 0.6965 - val_loss: 0.5617
# Epoch 16/70
# 537/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7471 - loss: 0.4939
# Epoch 16: val_accuracy did not improve from 0.83576
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7472 - loss: 0.4938 - val_accuracy: 0.7443 - val_loss: 0.4759
# Epoch 17/70
# 536/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7656 - loss: 0.4772
# Epoch 17: val_accuracy did not improve from 0.83576
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7656 - loss: 0.4772 - val_accuracy: 0.6694 - val_loss: 0.6028
# Epoch 18/70
# 536/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7601 - loss: 0.4673
# Epoch 18: val_accuracy improved from 0.83576 to 0.84200, saving model to ../models/melhor_rnn_PETR4.keras
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7601 - loss: 0.4673 - val_accuracy: 0.8420 - val_loss: 0.3886
# Epoch 19/70
# 539/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7857 - loss: 0.4418
# Epoch 19: val_accuracy did not improve from 0.84200
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7856 - loss: 0.4419 - val_accuracy: 0.8316 - val_loss: 0.3891
# Epoch 20/70
# 535/541 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8486 - loss: 0.3273 - val_accuracy: 0.7963 - val_loss: 0.4328
# Epoch 64/70
# 535/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8535 - loss: 0.3309
# Epoch 64: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8535 - loss: 0.3309 - val_accuracy: 0.6486 - val_loss: 0.7345
# Epoch 65/70
# 539/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8569 - loss: 0.3158
# Epoch 65: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8568 - loss: 0.3158 - val_accuracy: 0.7609 - val_loss: 0.4474
# Epoch 66/70
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8501 - loss: 0.3303
# Epoch 66: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8501 - loss: 0.3303 - val_accuracy: 0.6736 - val_loss: 0.7252
# Epoch 67/70
# 539/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8514 - loss: 0.3242
# Epoch 67: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8515 - loss: 0.3241 - val_accuracy: 0.7755 - val_loss: 0.4753
# Epoch 68/70
# 540/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8584 - loss: 0.3149
# Epoch 68: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8584 - loss: 0.3149 - val_accuracy: 0.7817 - val_loss: 0.5476
# Epoch 69/70
# 536/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8518 - loss: 0.3200
# Epoch 69: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8518 - loss: 0.3200 - val_accuracy: 0.7360 - val_loss: 0.5840
# Epoch 70/70
# 539/541 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8522 - loss: 0.3218
# Epoch 70: val_accuracy did not improve from 0.87734
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8523 - loss: 0.3218 - val_accuracy: 0.7422 - val_loss: 0.4786

# %%
def plotar_historico(historico, titulo):
    fig, ax1 = plt.subplots(figsize=(12, 5))

    color = 'tab:blue'
    ax1.set_xlabel('Épocas')
    ax1.set_ylabel('Acurácia', color=color)
    ax1.plot(historico.history['accuracy'], label='Acurácia de Treino', color=color)
    if 'val_accuracy' in historico.history:
        ax1.plot(historico.history['val_accuracy'], label='Acurácia de Validação', color=color, linestyle='--')
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.legend(loc='upper left')
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:red'
    ax2.set_ylabel('Perda', color=color)  # we already handled the x-label with ax1
    ax2.plot(historico.history['loss'], label='LOSS de Treino', color=color)
    if 'val_loss' in historico.history:
        ax2.plot(historico.history['val_loss'], label='LOSS de Validação', color=color, linestyle='--')
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.legend(loc='upper right')

    plt.title(titulo)
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()



plotar_historico(historico_rnn, f"Histórico de Treinamento - {nome_arquivo}")

# %%
plot_model(model_rnn,show_shapes=True, show_layer_names=True)

# %%
# Função para plotar a matriz de confusão
def plotar_matriz_confusao(cm, classes, title):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(title)

# Avaliar o modelo
scores = model_rnn.evaluate(X_test, y_test_cat, verbose=0)
print(f"{nome_arquivo} -> Acurácia: {scores[1]*100:.2f}%")

# Predições
y_pred = model_rnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_teste_classes = np.argmax(y_test_cat, axis=1)

# Gerar e plotar a matriz de confusão
cm = confusion_matrix(y_teste_classes, y_pred_classes)
plotar_matriz_confusao(cm, classes=['Classe 0', 'Classe 1'], title=f'Matriz de Confusão para {nome_arquivo}')

# Gerar relatório de classificação
print(f"Relatório de Classificação para {nome_arquivo}:\n {classification_report(y_teste_classes, y_pred_classes)}\n")
# Out:
# PETR4 -> Acurácia: 57.27%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Relatório de Classificação para PETR4:
#                precision    recall  f1-score   support
#
#            0       0.54      0.74      0.63       581
#            1       0.63      0.42      0.50       622
#
#     accuracy                           0.57      1203
#    macro avg       0.59      0.58      0.56      1203
# weighted avg       0.59      0.57      0.56      1203
