# %% [markdown]
# # Projeto Integrado Final - Deep Learning
#
# Desenvolvimento de modelo classificação utilizando Redes Neurais Convolucionais (CNN) ou Redes Neurais Recorrentes (RNN), com base na tendencia de mercado dos ultimos 15 dias, considerando o "close" da ação em base de dados suavizada.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.utils import to_categorical, plot_model
from keras.callbacks import ModelCheckpoint
from collections import defaultdict

# %%
df_train = pd.read_csv('../data/BBAS3.SA/treino.csv')
df_test = pd.read_csv('../data/BBAS3.SA/teste.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_train.head(2)
# Out:
#    Unnamed: 0        Date     Close  Smoothed_Close  Label  Past_1_Days_Close  \
# 0           1  2000-01-24  1.062769        1.071645     -1           1.088979
# 1           2  2000-01-26  1.087668        1.073247     -1           1.062769
#
#    Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  Past_5_Days_Close  \
# 0           1.079805           1.086357           1.098152           1.069322
# 1           1.088979           1.079805           1.086357           1.098152
#
#    Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# 0           1.061459           1.062769           1.081116           1.066701
# 1           1.069322           1.061459           1.062769           1.081116
#
#    Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# 0            1.081116            1.024767            1.048355
# 1            1.066701            1.081116            1.024767
#
#    Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# 0            1.033940            1.023457            1.074564
# 1            1.048355            1.033940            1.023457

# %%
df_test.head(2)
# Out:
#    Unnamed: 0        Date      Close  Smoothed_Close  Label  \
# 0        4736  2019-03-26  36.386158       37.917648     -1
# 1        4737  2019-03-27  34.371300       37.563014     -1
#
#    Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  Past_4_Days_Close  \
# 0          35.549099          35.297241          37.326935          38.126942
# 1          36.386158          35.549099          35.297241          37.326935
#
#    Past_5_Days_Close  Past_6_Days_Close  Past_7_Days_Close  Past_8_Days_Close  \
# 0          39.001053          39.852917          40.156639          39.815880
# 1          38.126942          39.001053          39.852917          40.156639
#
#    Past_9_Days_Close  Past_10_Days_Close  Past_11_Days_Close  \
# 0          40.119583           39.512161           39.737267
# 1          39.815880           40.119583           39.512161
#
#    Past_12_Days_Close  Past_13_Days_Close  Past_14_Days_Close  \
# 0           38.555489           37.248150           37.395866
# 1           39.737267           38.555489           37.248150
#
#    Past_15_Days_Close
# 0           37.898129
# 1           37.395866

# %%
nome_arquivo = 'BBAS3'
# EDA
print(f"EDA para {nome_arquivo}:")
print(f"Descrição dos dados:\n{df_train.describe()}\n")
print(f"Contagem de valores NaN por coluna:\n{df_train.isna().sum()}\n")
print(f"Contagem dos rótulos:\n{df_train['Label'].value_counts()}\n")
# Out:
# EDA para BBAS3:
# Descrição dos dados:
#         Unnamed: 0        Close  Smoothed_Close        Label  \
# count  4735.000000  4735.000000     4735.000000  4735.000000
# mean   2368.000000    10.170651       10.100295    -0.099050
# std    1367.021092     7.438277        7.315907     0.995188
# min       1.000000     0.720744        0.761192    -1.000000
# 25%    1184.500000     3.770148        3.808185    -1.000000
# 50%    2368.000000    10.732536       10.879908    -1.000000
# 75%    3551.500000    13.233261       13.129158     1.000000
# max    4735.000000    40.156639       38.947137     1.000000
#
#        Past_1_Days_Close  Past_2_Days_Close  Past_3_Days_Close  \
# count        4735.000000        4735.000000        4735.000000
# mean           10.163374          10.156147          10.148493
# std             7.430295           7.422481           7.413137
# min             0.720744           0.720744           0.720744
# 25%             3.767527           3.751146           3.731489
# 50%            10.731052          10.728116          10.726274
# 75%            13.231621          13.231257          13.229957
# max            40.156639          40.156639          40.156639
#
#        Past_4_Days_Close  Past_5_Days_Close  Past_6_Days_Close  \
# count        4735.000000        4735.000000        4735.000000
# mean           10.140673          10.132662          10.124470
# std             7.403140           7.392419           7.380961
# min             0.720744           0.720744           0.720744
# 25%             3.728212           3.724280           3.715107
# 50%            10.725977          10.724441          10.723884
# 75%            13.228519          13.227788          13.226579
# max            40.156639          40.156639          40.156639
#
#        Past_7_Days_Close  Past_8_Days_Close  Past_9_Days_Close  \
# count        4735.000000        4735.000000        4735.000000
# mean           10.116213          10.108033          10.099785
# std             7.369216           7.357730           7.345960
# min             0.720744           0.720744           0.720744
# 25%             3.709865           3.703313           3.696107
# 50%            10.719409          10.716810          10.712873
# 75%            13.221962          13.217677          13.213695
# max            40.119583          40.119583          40.032852
#
#        Past_10_Days_Close  Past_11_Days_Close  Past_12_Days_Close  \
# count         4735.000000         4735.000000         4735.000000
# mean            10.091669           10.083493           10.075572
# std              7.334678            7.323193            7.312667
# min              0.720744            0.720744            0.720744
# 25%              3.694797            3.691521            3.685624
# 50%             10.703439           10.693220           10.693220
# 75%             13.210227           13.207818           13.202331
# max             40.032852           40.032852           40.032852
#
#        Past_13_Days_Close  Past_14_Days_Close  Past_15_Days_Close
# count         4735.000000         4735.000000         4735.000000
# mean            10.067924           10.060242           10.052465
# std              7.303173            7.293545            7.283481
# min              0.720744            0.720744            0.720744
# 25%              3.682347            3.676450            3.669898
# 50%             10.693220           10.693220           10.693220
# 75%             13.198335           13.192680           13.187670
# max             40.032852           40.032852           40.032852
#
# Contagem de valores NaN por coluna:
# Unnamed: 0            0
# Date                  0
# Close                 0
# Smoothed_Close        0
# Label                 0
# Past_1_Days_Close     0
# Past_2_Days_Close     0
# Past_3_Days_Close     0
# Past_4_Days_Close     0
# Past_5_Days_Close     0
# Past_6_Days_Close     0
# Past_7_Days_Close     0
# Past_8_Days_Close     0
# Past_9_Days_Close     0
# Past_10_Days_Close    0
# Past_11_Days_Close    0
# Past_12_Days_Close    0
# Past_13_Days_Close    0
# Past_14_Days_Close    0
# Past_15_Days_Close    0
# dtype: int64
#
# Contagem dos rótulos:
# Label
# -1    2602
#  1    2133
# Name: count, dtype: int64

# %%
# COMPARAÇÃO ENTRE PREÇOS DE FECHAMENTO E PREÇOS DE FECHAMENTO SUAVIZADOS
plt.figure(figsize=(14, 7))
plt.plot(df_train['Close'], label='Close')
plt.plot(df_train['Smoothed_Close'], label='Smoothed Close')
plt.title(f'Preços de Fechamento e Suavizados - {nome_arquivo}')
plt.legend()
plt.show()

# %%
# DISTRIBUIÇÃO DOS RÓTULOS
sns.countplot(x='Label', data=df_train)
plt.title(f'Distribuição de Classes - {nome_arquivo}')
plt.show()

# %% [markdown]
# ## Treinamento de modelo de Redes Neurais Recorrentes (RNN)

# %%
## NORMALIZAÇÃO DOS DADOS

# Normalizador para as features
scaler = StandardScaler()

# Função para converter rótulos em formato categórico
def converter_para_categorico(y):
    if y.min() == -1:  # Se os rótulos forem -1 e 1
        y = (y + 1) // 2  # Converter rótulos para 0 e 1
    return to_categorical(y)

X_train = df_train.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_train = df_train['Label']

X_test = df_test.drop(['Date', 'Close', 'Smoothed_Close', 'Label'], axis=1)
y_test = df_test['Label']

# Normalizar as features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Converter os rótulos para formato categórico
y_train_cat = converter_para_categorico(y_train)
y_test_cat = converter_para_categorico(y_test)

# %%
# Cria e treina a rede LSTM
historicos = {}

model_rnn = Sequential([
        LSTM(150, return_sequences=True, input_shape=(X_train.shape[1], 1)),
        Dropout(0.2),
        LSTM(50, return_sequences=False, activation='relu'),
        Dense(y_train_cat.shape[1], activation='sigmoid')
    ])

# Compilando o modelo com entropia cruzada categórica para classificação binária
# A acurácia é usada como métrica para avaliação
model_rnn.compile(loss='binary_crossentropy', metrics=['accuracy'])

# Treinando o modelo com os dados
# Epochs define o número de vezes que o modelo verá todo o conjunto de dados
# Batch size é o número de amostras que o modelo vê antes de atualizar os pesos
# Verbose=1 mostra a barra de progresso do treinamento

checkpointer = ModelCheckpoint(filepath='../models/melhor_rnn_BBAS3.keras', verbose=1,  save_best_only=True, monitor='val_accuracy')

historico_rnn = model_rnn.fit(X_train, y_train_cat, epochs=100, batch_size=8, validation_split=0.2, verbose=1, callbacks=[checkpointer],shuffle=True)
# Out:
# Epoch 1/100
# /Users/cintia.duarte/Documents/develop/NEURAL-NETWORKS-REGRESSION/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 469/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5507 - loss: 0.6881
# Epoch 1: val_accuracy improved from -inf to 0.51426, saving model to ../models/melhor_rnn_BBAS3.keras
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5508 - loss: 0.6880 - val_accuracy: 0.5143 - val_loss: 0.8252
# Epoch 2/100
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5565 - loss: 0.6761
# Epoch 2: val_accuracy improved from 0.51426 to 0.57233, saving model to ../models/melhor_rnn_BBAS3.keras
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5565 - loss: 0.6760 - val_accuracy: 0.5723 - val_loss: 4.7236
# Epoch 3/100
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6425 - loss: 0.6304
# Epoch 3: val_accuracy did not improve from 0.57233
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6425 - loss: 0.6304 - val_accuracy: 0.5713 - val_loss: 4.3124
# Epoch 4/100
# 473/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6607 - loss: 0.6033
# Epoch 4: val_accuracy improved from 0.57233 to 0.60718, saving model to ../models/melhor_rnn_BBAS3.keras
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6607 - loss: 0.6033 - val_accuracy: 0.6072 - val_loss: 1.8144
# Epoch 5/100
# 469/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6530 - loss: 0.5924
# Epoch 5: val_accuracy did not improve from 0.60718
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6532 - loss: 0.5924 - val_accuracy: 0.5702 - val_loss: 4.0988
# Epoch 6/100
# 469/474 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6603 - loss: 0.5874
# Epoch 6: val_accuracy did not improve from 0.60718
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6604 - loss: 0.5874 - val_accuracy: 0.5776 - val_loss: 4.4265
# Epoch 7/100
# 470/474 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6662 - loss: 0.5916
# Epoch 7: val_accuracy did not improve from 0.60718
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6663 - loss: 0.5915 - val_accuracy: 0.5713 - val_loss: 3.9636
# Epoch 8/100
# 473/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6788 - loss: 0.5957
# Epoch 8: val_accuracy did not improve from 0.60718
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6789 - loss: 0.5957 - val_accuracy: 0.5713 - val_loss: 2.1281
# Epoch 9/100
# 468/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6894 - loss: 0.5705
# Epoch 9: val_accuracy improved from 0.60718 to 0.63358, saving model to ../models/melhor_rnn_BBAS3.keras
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6893 - loss: 0.5706 - val_accuracy: 0.6336 - val_loss: 2.3459
# Epoch 10/100
# 472/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6829 - loss: 0.5640
# Epoch 10: val_accuracy did not improve from 0.63358
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6829 - loss: 0.5640 - val_accuracy: 0.5618 - val_loss: 2.5475
# Epoch 11/100
# 471/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6975 - loss: 0.5570
# Epoch 11: val_accuracy did not improve from 0.63358
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6974 - loss: 0.5571 - val_accuracy: 0.6040 - val_loss: 2.7746
# Epoch 12/100
# 470/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7935 - loss: 0.4866 - val_accuracy: 0.6072 - val_loss: 3.9280
# Epoch 93/100
# 472/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7894 - loss: 0.5423
# Epoch 93: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7894 - loss: 0.5422 - val_accuracy: 0.6199 - val_loss: 3.9338
# Epoch 94/100
# 473/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7981 - loss: 0.5489
# Epoch 94: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7981 - loss: 0.5510 - val_accuracy: 0.5607 - val_loss: 95.6651
# Epoch 95/100
# 468/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8069 - loss: 0.4330
# Epoch 95: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8066 - loss: 0.4332 - val_accuracy: 0.6399 - val_loss: 23.2527
# Epoch 96/100
# 470/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7744 - loss: 0.4408
# Epoch 96: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7745 - loss: 0.4413 - val_accuracy: 0.5839 - val_loss: 18.4806
# Epoch 97/100
# 471/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7998 - loss: 0.7604
# Epoch 97: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7997 - loss: 0.7594 - val_accuracy: 0.5343 - val_loss: 149.2074
# Epoch 98/100
# 468/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7858 - loss: 0.4693
# Epoch 98: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7858 - loss: 0.4690 - val_accuracy: 0.5713 - val_loss: 4.0830
# Epoch 99/100
# 473/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7802 - loss: 3.1853
# Epoch 99: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7802 - loss: 3.1918 - val_accuracy: 0.5438 - val_loss: 69.1052
# Epoch 100/100
# 470/474 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7731 - loss: 0.5961
# Epoch 100: val_accuracy did not improve from 0.82365
# 474/474 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7732 - loss: 0.5980 - val_accuracy: 0.6336 - val_loss: 42.0988

# %%
def plotar_historico(historico, titulo):
    plt.figure(figsize=(12, 5))
    plt.plot(historico.history['accuracy'], label='Acurácia de Treino')
    if 'val_accuracy' in historico.history:
        plt.plot(historico.history['val_accuracy'], label='Acurácia de Validação')
    plt.plot(historico.history['loss'], label='LOSS de Treino')
    if 'val_loss' in historico.history:
        plt.plot(historico.history['val_loss'], label='LOSS de Validação')
    plt.title(titulo)
    plt.xlabel('Épocas')
    plt.ylabel('Acurácia / Perda')
    plt.legend()
    plt.show()

plotar_historico(historico_rnn, f"Histórico de Treinamento - {nome_arquivo}")

# %%
plot_model(model_rnn,show_shapes=True, show_layer_names=True)

# %%
# Função para plotar a matriz de confusão
def plotar_matriz_confusao(cm, classes, title):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(title)

# Avaliar o modelo
scores = model_rnn.evaluate(X_test, y_test_cat, verbose=0)
print(f"{nome_arquivo} -> Acurácia: {scores[1]*100:.2f}%")

# Predições
y_pred = model_rnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_teste_classes = np.argmax(y_test_cat, axis=1)

# Gerar e plotar a matriz de confusão
cm = confusion_matrix(y_teste_classes, y_pred_classes)
plotar_matriz_confusao(cm, classes=['Classe 0', 'Classe 1'], title=f'Matriz de Confusão para {nome_arquivo}')

# Gerar relatório de classificação
print(f"Relatório de Classificação para {nome_arquivo}:\n {classification_report(y_teste_classes, y_pred_classes)}\n")
# Out:
# BBAS3 -> Acurácia: 52.32%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Relatório de Classificação para BBAS3:
#                precision    recall  f1-score   support
#
#            0       0.57      0.75      0.65       689
#            1       0.38      0.21      0.27       496
#
#     accuracy                           0.52      1185
#    macro avg       0.47      0.48      0.46      1185
# weighted avg       0.49      0.52      0.49      1185

# %% [markdown]
# ## Treinamento de Redes Neurais Convolucionais (CNN)
